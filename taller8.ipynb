# %% [markdown]
# <a href="https://colab.research.google.com/github/dvillanueva123/Cd-202202_Darinel_Villanueva/blob/main/taller8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm

# %%
df= pd.read_csv("https://raw.githubusercontent.com/adiacla/bigdata/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df= df.drop('Cabin',axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x= df.iloc[:,[5,6,7,9]]
y= df.Survived
logit_model= sm.Logit(y,x)
result= logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.616032
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      708
# Method:                           MLE   Df Model:                            3
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                 0.08708
# Time:                        13:49:32   Log-Likelihood:                -438.62
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                 4.998e-18
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0281      0.003     -8.205      0.000      -0.035      -0.021
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size = 0.80, shuffle = False)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 172          173         1       3
# 173          174         0       3
# 174          175         0       1
# 175          176         0       3
# 177          178         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 178          179         0       2                     Hale, Mr. Reginald
# 179          180         0       3                    Leonard, Mr. Lionel
# 182          183         0       3  Asplund, Master. Clarence Gustaf Hugo
# 183          184         1       2              Becker, Master. Richard F
# 184          185         1       3    Kink-Heilmann, Miss. Luise Gretchen
# ..           ...       ...     ...                                    ...
# 885          886         0       3   Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                  Montvila, Rev. Juozas
# 887          888         1       1           Graham, Miss. Margaret Edith
# 889          890         1       1                  Behr, Mr. Karl Howell
# 890          891         0       3                    Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Embarked
# ...

# %%
x= test.iloc[:,[5,6,7,9]]
y= test.Survived
logit_model= sm.Logit(y,x)
result= logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.602802
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  570
# Model:                          Logit   Df Residuals:                      566
# Method:                           MLE   Df Model:                            3
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                  0.1171
# Time:                        14:05:46   Log-Likelihood:                -343.60
# converged:                       True   LL-Null:                       -389.18
# Covariance Type:            nonrobust   LLR p-value:                 1.236e-19
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0304      0.004     -7.679      0.000      -0.038      -0.023
# ...
